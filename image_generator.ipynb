# %% [markdown]
# <center><h1>Image regeneration using GA</h1></center>

# %% [markdown]
# ### 0. Importing all the necessary libraries

# %%
import re
import os
import cv2
import shutil
import random
import imageio
import operator
import functools
import itertools
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import randint

# %% [markdown]
# ### 1. Defining global constants

# %%
qualities = []
num_parents_mating = 3
mutation_percent = 2
sol_per_pop = 8

# %% [markdown]
# ### 2. Reading the image for experiment

# %%
face = cv2.imread('face.png')
face = cv2.cvtColor(face, cv2.COLOR_BGR2GRAY)
M, N = face.shape[:2]

# %% [markdown]
# ### 3. Data representation

# %%
def img2vector(img):
    return np.reshape(a=img, newshape=(functools.reduce(operator.mul, img.shape)))

# %%
def convert2img(chromo, imgShape):
    return np.reshape(a=chromo, newshape=imgShape)

# %% [markdown]
# ### 4. Generating initial population

# %%
def initialPopulation(imgShape, nIndividuals=8):
    init_population = np.empty(shape=(nIndividuals, functools.reduce(operator.mul, imgShape)), dtype = np.uint8)
    for indv_num in range(nIndividuals):
        init_population[indv_num, :] = randint(0,2,M*N)
    return init_population

# %% [markdown]
# ### 5. Calculating fitness

# %%
def fitness_func(target, chromo):
    return -1*np.sum(np.abs(chromo-target))

def calPopFitness(target,pop):
    qualities = np.zeros(pop.shape[0])
    for num in range(pop.shape[0]):
        qualities[num] = fitness_func(target, pop[num, :])
    return qualities

# %% [markdown]
# ### 6. Selection

# %%
def getBestParents(population,qualities,n=4):
    parents = []
    i = np.argsort(qualities)[::-1]
    n_fit=np.sort(qualities)[::-1]
    print('Index of best -{}'.format(i))
    print('Best qualites -{}'.format(n_fit))
    best_parent_index = i[0:n]
    for j in best_parent_index:
        parents.append(population[j])
    parents=np.array(parents)
    return parents

# %% [markdown]
# ### 7. Crossover

# %%
def crossover(parents, imgShape, nIndividuals=8):
    new_population = np.empty(shape=(nIndividuals,functools.reduce(operator.mul, imgShape)),dtype = np.uint8)
    new_population[0:parents.shape[0], :] = parents
    num_newly_generated = nIndividuals-parents.shape[0]
    parents_permutations = list(itertools.permutations(iterable=np.arange(0, parents.shape[0]),r=2))
    selected_permutations = random.sample(range(len(parents_permutations)),num_newly_generated)
    comb_idx = parents.shape[0]
    for comb in range(len(selected_permutations)):
        selected_comb_idx = selected_permutations[comb]
        selected_comb = parents_permutations[selected_comb_idx]
        cross_size = np.int32(new_population.shape[1]/50)
        new_population[comb_idx+comb, 0:cross_size] = parents[selected_comb[0],0:cross_size]
        new_population[comb_idx+comb, cross_size:] = parents[selected_comb[1],cross_size:]
    return new_population

# %% [markdown]
# ### 8. Mutation

# %%
def mutation(population, numParentsMating, mutPercent):
    for i in range(numParentsMating, population.shape[0]):
        rand_indx = np.uint32(np.random.random(size=np.uint32(mutPercent/100*population.shape[1]))*population.shape[1])
        new_values = randint(0, 2, len(rand_indx))
        population[i, rand_indx] = new_values
    return population

# %% [markdown]
# ### 9. Some utility functions

# %%
def flush_dir(directory):
    shutil.rmtree(directory)
    os.makedirs(directory)

# %%
def natural_sort_key(s):
    return [int(text) if text.isdigit() else text.lower() for text in re.split(r'(\d+)', s)]

# %%
def saveImages(currIteration, qualities, population, imShape, save_point, save_dir):
    if(np.mod(currIteration+1, save_point)==0):
        best_solution_chrom = population[np.where(qualities == np.max(qualities))[0][0],:]
        best_solution_img = convert2img(best_solution_chrom, imShape)
        fig,a = plt.subplots(1,2)
        fig.suptitle(f'Iteration {currIteration+1}')
        a[0].imshow(best_solution_img)
        a[0].set_title('Best Solution')
        a[1].imshow(face)
        a[1].set_title('Original')
        plt.savefig(f'{save_dir}/{currIteration+1}.png')
        plt.close(fig)

# %% [markdown]
# ### 10. Regenerating the image

# %%
faceVector = img2vector(face)/255
population = initialPopulation((M,N))
flush_dir('image')
for iteration in range(250):
    qualities = calPopFitness(faceVector, population)
    print('Quality: ', qualities)
    print('Iteration : ', iteration)
    parents = getBestParents(population, qualities, num_parents_mating)
    population = crossover(parents, (M,N), nIndividuals = sol_per_pop)
    population = mutation(population= population,numParentsMating=num_parents_mating,mutPercent=mutation_percent)
    saveImages(iteration, qualities,population, (M,N), save_point= 1, save_dir= os.path.join(os.curdir,'image'))
# Out:
# Quality:  [-53. -55. -48. -46. -52. -52. -48. -52.]
# Iteration :  0
# Index of best -[3 6 2 7 5 4 0 1]
# Best qualites -[-46. -48. -48. -52. -52. -52. -53. -55.]
# Quality:  [-46. -48. -48. -48. -47. -47. -48. -47.]
# Iteration :  1
# Index of best -[0 7 5 4 6 3 2 1]
# Best qualites -[-46. -47. -47. -47. -48. -48. -48. -48.]
# Quality:  [-46. -47. -47. -47. -48. -47. -45. -45.]
# Iteration :  2
# Index of best -[7 6 0 5 3 2 1 4]
# Best qualites -[-45. -45. -46. -47. -47. -47. -47. -48.]
# Quality:  [-45. -45. -46. -45. -47. -45. -45. -46.]
# Iteration :  3
# Index of best -[6 5 3 1 0 7 2 4]
# Best qualites -[-45. -45. -45. -45. -45. -46. -46. -47.]
# Quality:  [-45. -45. -45. -46. -45. -46. -46. -44.]
# Iteration :  4
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[-44. -45. -45. -45. -45. -46. -46. -46.]
# Quality:  [-44. -45. -45. -43. -46. -44. -44. -46.]
# Iteration :  5
# Index of best -[3 6 5 0 2 1 7 4]
# Best qualites -[-43. -44. -44. -44. -45. -45. -46. -46.]
# Quality:  [-43. -44. -44. -46. -43. -42. -43. -45.]
# Iteration :  6
# Index of best -[5 6 4 0 2 1 7 3]
# Best qualites -[-42. -43. -43. -43. -44. -44. -45. -46.]
# Quality:  [-42. -43. -43. -42. -42. -42. -42. -42.]
# Iteration :  7
# Index of best -[7 6 5 4 3 0 2 1]
# Best qualites -[-42. -42. -42. -42. -42. -42. -43. -43.]
# Quality:  [-42. -42. -42. -43. -43. -43. -41. -43.]
# Iteration :  8
# Index of best -[6 2 1 0 7 5 4 3]
# Best qualites -[-41. -42. -42. -42. -43. -43. -43. -43.]
# Quality:  [-41. -42. -42. -41. -42. -43. -43. -42.]
# Iteration :  9
# Index of best -[3 0 7 4 2 1 6 5]
# Best qualites -[-41. -41. -42. -42. -42. -42. -43. -43.]
# Quality:  [-41. -41. -42. -41. -42. -42. -41. -41.]
# Iteration :  10
# Index of best -[7 6 3 1 0 5 4 2]
# Best qualites -[-41. -41. -41. -41. -41. -42. -42. -42.]
# Quality:  [-41. -41. -41. -42. -42. -42. -40. -42.]
# Iteration :  11
# Index of best -[6 2 1 0 7 5 4 3]
# Best qualites -[
# Quality:  [-32. -32. -32. -34. -31. -31. -31. -34.]
# Iteration :  28
# Index of best -[6 5 4 2 1 0 7 3]
# Best qualites -[-31. -31. -31. -32. -32. -32. -34. -34.]
# Quality:  [-31. -31. -31. -32. -30. -31. -32. -31.]
# Iteration :  29
# Index of best -[4 7 5 2 1 0 6 3]
# Best qualites -[-30. -31. -31. -31. -31. -31. -32. -32.]
# Quality:  [-30. -31. -31. -32. -30. -29. -32. -29.]
# Iteration :  30
# Index of best -[7 5 4 0 2 1 6 3]
# Best qualites -[-29. -29. -30. -30. -31. -31. -32. -32.]
# Quality:  [-29. -29. -30. -29. -30. -29. -32. -29.]
# Iteration :  31
# Index of best -[7 5 3 1 0 4 2 6]
# Best qualites -[-29. -29. -29. -29. -29. -30. -30. -32.]
# Quality:  [-29. -29. -29. -29. -28. -32. -30. -28.]
# Iteration :  32
# Index of best -[7 4 3 2 1 0 6 5]
# Best qualites -[-28. -28. -29. -29. -29. -29. -30. -32.]
# Quality:  [-28. -28. -29. -28. -28. -29. -28. -29.]
# Iteration :  33
# Index of best -[6 4 3 1 0 7 5 2]
# Best qualites -[-28. -28. -28. -28. -28. -29. -29. -29.]
# Quality:  [-28. -28. -28. -27. -30. -27. -27. -30.]
# Iteration :  34
# Index of best -[6 5 3 2 1 0 7 4]
# Best qualites -[-27. -27. -27. -28. -28. -28. -30. -30.]
# Quality:  [-27. -27. -27. -29. -28. -28. -29. -26.]
# Iteration :  35
# Index of best -[7 2 1 0 5 4 6 3]
# Best qualites -[-26. -27. -27. -27. -28. -28. -29. -29.]
# Quality:  [-26. -27. -27. -27. -28. -27. -26. -26.]
# Iteration :  36
# Index of best -[7 6 0 5 3 2 1 4]
# Best qualites -[-26. -26. -26. -27. -27. -27. -27. -28.]
# Quality:  [-26. -26. -26. -26. -27. -26. -24. -26.]
# Iteration :  37
# Index of best -[6 7 5 3 2 1 0 4]
# Best qualites -[-24. -26. -26. -26. -26. -26. -26. -27.]
# Quality:  [-24. -26. -26. -25. -25. -26. -25. -25.]
# Iteration :  38
# Index of best -[0 7 6 4 3 5 2 1]
# Best qualites -[-24. -25. -25. -25. -25. -26. -26. -26.]
# Quality:  [-24. -25. -25. -26. -26. -24. -26. -25.]
# Iteration :  39
# Index of best -[5 0 7 2 1 6 4 3]
# Best qualites -[-24. -24. -25. -25. -25. -26. -26. -26.]
# Quality:  [-24. -24. -25. -27. -26. -24. -23. -26.]
# Iteration :  40
# Index of best -[6 5 1 0 2 7 4 3]
# Best qualites -[-23. -24. -24. -24. -25. -26. -26. -27.]
# Quality:  [-23. -24. -24. -22. -25. -25. -24. -23.]
# Iteration :  41
# Index of best -[3 7 0 6 2 1 5 4]
# Best qualites -[-22. -23. -23. -24. -24. -24. -25. -25.]
# Quality:  [-22. -23. -23. -23. -23. -23. -22. -23.]
# Iteration :  42
# Index of best -[6 0 7 5 4 3 2 1]
# Best qualites -[-22. -22. -23. -23. -23. -23. -23. -23.]
# Quality:  [-22. -22. -23. -22. -22. -23. -22. -22.]
# Iteration :  43
# Index of best -[7 6 4 3 1 0 5 2]
# Index of best -[6 3 2 1 0 7 5 4]
# Best qualites -[-10. -10. -10. -10. -10. -11. -11. -11.]
# Quality:  [-10. -10. -10. -10. -11.  -9. -12. -11.]
# Iteration :  93
# Index of best -[5 3 2 1 0 7 4 6]
# Best qualites -[ -9. -10. -10. -10. -10. -11. -11. -12.]
# Quality:  [ -9. -10. -10.  -9. -10. -12. -10. -12.]
# Iteration :  94
# Index of best -[3 0 6 4 2 1 7 5]
# Best qualites -[ -9.  -9. -10. -10. -10. -10. -12. -12.]
# Quality:  [ -9.  -9. -10. -10. -10. -10. -11. -10.]
# Iteration :  95
# Index of best -[1 0 7 5 4 3 2 6]
# Best qualites -[ -9.  -9. -10. -10. -10. -10. -10. -11.]
# Quality:  [ -9.  -9. -10. -11. -10. -10. -10.  -9.]
# Iteration :  96
# Index of best -[7 1 0 6 5 4 2 3]
# Best qualites -[ -9.  -9.  -9. -10. -10. -10. -10. -11.]
# Quality:  [ -9.  -9.  -9.  -9. -10. -11. -10.  -9.]
# Iteration :  97
# Index of best -[7 3 2 1 0 6 4 5]
# Best qualites -[ -9.  -9.  -9.  -9.  -9. -10. -10. -11.]
# Quality:  [ -9.  -9.  -9. -11. -11.  -9. -10. -10.]
# Iteration :  98
# Index of best -[5 2 1 0 7 6 4 3]
# Best qualites -[ -9.  -9.  -9.  -9. -10. -10. -11. -11.]
# Quality:  [ -9.  -9.  -9. -11. -10. -10. -10. -10.]
# Iteration :  99
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[ -9.  -9.  -9. -10. -10. -10. -10. -11.]
# Quality:  [ -9.  -9.  -9. -11.  -9. -11. -11.  -9.]
# Iteration :  100
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[ -9.  -9.  -9.  -9.  -9. -11. -11. -11.]
# Quality:  [ -9.  -9.  -9. -10. -10. -10. -10.  -9.]
# Iteration :  101
# Index of best -[7 2 1 0 6 5 4 3]
# Best qualites -[ -9.  -9.  -9.  -9. -10. -10. -10. -10.]
# Quality:  [ -9.  -9.  -9. -11. -10.  -9. -10. -10.]
# Iteration :  102
# Index of best -[5 2 1 0 7 6 4 3]
# Best qualites -[ -9.  -9.  -9.  -9. -10. -10. -10. -11.]
# Quality:  [ -9.  -9.  -9. -10.  -8. -10. -11.  -9.]
# Iteration :  103
# Index of best -[4 7 2 1 0 5 3 6]
# Best qualites -[ -8.  -9.  -9.  -9.  -9. -10. -10. -11.]
# Quality:  [ -8.  -9.  -9.  -9. -10. -10.  -9.  -9.]
# Iteration :  104
# Index of best -[0 7 6 3 2 1 5 4]
# Best qualites -[ -8.  -9.  -9.  -9.  -9.  -9. -10. -10.]
# Quality:  [ -8.  -9.  -9.  -9. -10.  -9. -11. -11.]
# Iteration :  105
# Index of best -[0 5 3 2 1 4 7 6]
# Best qualites -[ -8.  -9.  -9.  -9.  -9. -10. -11. -11.]
# Quality:  [ -8.  -9.  -9. -11.  -9. -10.  -9.  -7.]
# Iteration :  106
# Index of best -[7 0 6 4 2 1 5 3]
# Best qualites -[ -7.  -8.  -9.  -9.  -9.  -9. -10. -11.]
# Quality:  [ -7.  -8.  -9.  -6. -10. -10.  -9.  -8.]
# Iteration :  107
# Index of best -[3 0 7 1 6 2 5 4]
# Best qualites -[ -6.  -7.  -8.  -8.  -9.  -9. -10. -10.]
# Quality:  [-6. -7. -8. -7. -9. -8. -9. -6.]
# Iteration :  108
# Index of best -[7 0 3 1 5 2 6 4]
# Best qualites -[-6. -6. -7. -7. -8. -8. -9. -9.]
# Quality:  [-6. -6. -7. -8. -8. -7. -8. -7.]
# Iteration :  109
# Index of best -[1 0 7 5 2 6 4 3]
# Best qualites -[-6. -6. -7. -7. -7. -8. -8. -8.]
# Quality:  [-6. -6. -7. -9. -8. -7. -8. -7.]
# Iteration :  110
# Index of best -[1 0 7 5 2 6 4 3]
# Best qualites -[-6. -6. -7. -7. -7. -8. -8. -9.]
# Quality:  [-6. -6. -7. -7. -7. -8. -6. -6.]
# Iteration :  111
# Index of best -[7 6 1 0 4 3 2 5]
# Best qualites -[-6. -6. -6. -6. -7. -7. -7. -8.]
# Quality:  [-6. -6. -6. -7. -7. -8. -7. -8.]
# Iteration :  112
# Index of best -[2 1 0 6 4 3 7 5]
# Best qualites -[-6. -6. -6. -7. -7. -7. -8. -8.]
# Quality:  [-6. -6. -6. -8. -7. -7. -6. -8.]
# Iteration :  113
# Index of best -[6 2 1 0 5 4 7 3]
# Best qualites -[-6. -6. -6. -6. -7. -7. -8. -8.]
# Quality:  [-6. -6. -6. -8. -6. -6. -7. -7.]
# Iteration :  114
# Index of best -[5 4 2 1 0 7 6 3]
# Best qualites -[-6. -6. -6. -6. -6. -7. -7. -8.]
# Quality:  [-6. -6. -6. -6. -7. -6. -7. -7.]
# Iteration :  115
# Index of best -[5 3 2 1 0 7 6 4]
# Best qualites -[-6. -6. -6. -6. -6. -7. -7. -7.]
# Quality:  [-6. -6. -6. -7. -7. -8. -6. -6.]
# Iteration :  116
# Index of best -[7 6 2 1 0 4 3 5]
# Best qualites -[-6. -6. -6. -6. -6. -7. -7. -8.]
# Quality:  [-6. -6. -6. -8. -6. -7. -7. -7.]
# Iteration :  117
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-6. -6. -6. -6. -7. -7. -7. -8.]
# Quality:  [-6. -6. -6. -6. -7. -6. -8. -6.]
# Iteration :  118
# Index of best -[7 5 3 2 1 0 4 6]
# Best qualites -[-6. -6. -6. -6. -6. -6. -7. -8.]
# Quality:  [-6. -6. -6. -7. -7. -7. -8. -7.]
# Iteration :  119
# Index of best -[2 1 0 7 5 4 3 6]
# Best qualites -[-6. -6. -6. -7. -7. -7. -7. -8.]
# Quality:  [-6. -6. -6. -8. -7. -7. -8. -7.]
# Iteration :  120
# Index of best -[2 1 0 7 5 4 6 3]
# Best qualites -[-6. -6. -6. -7. -7. -7. -8. -8.]
# Quality:  [-6. -6. -6. -6. -6. -7. -7. -8.]
# Iteration :  121
# Index of best -[4 3 2 1 0 6 5 7]
# Best qualites -[-6. -6. -6. -6. -6. -7. -7. -8.]
# Quality:  [-6. -6. -6. -5. -6. -6. -7. -6.]
# Iteration :  122
# Index of best -[3 7 5 4 2 1 0 6]
# Best qualites -[-5. -6. -6. -6. -6. -6. -6. -7.]
# Quality:  [-5. -6. -6. -6. -5. -6. -7. -6.]
# Iteration :  123
# Index of best -[4 0 7 5 3 2 1 6]
# Best qualites -[-5. -5. -6. -6. -6. -6. -6. -7.]
# Quality:  [-5. -5. -6. -7. -5. -5. -4. -6.]
# Iteration :  124
# Index of best -[6 5 4 1 0 7 2 3]
# Best qualites -[-4. -5. -5. -5. -5. -6. -6. -7.]
# Quality:  [-4. -5. -5. -6. -5. -6. -6. -5.]
# Iteration :  125
# Index of best -[0 7 4 2 1 6 5 3]
# Best qualites -[-4. -5. -5. -5. -5. -6. -6. -6.]
# Quality:  [-4. -5. -5. -6. -6. -4. -5. -6.]
# Iteration :  126
# Index of best -[5 0 6 2 1 7 4 3]
# Best qualites -[-4. -4. -5. -5. -5. -6. -6. -6.]
# Quality:  [-4. -4. -5. -6. -6. -5. -5. -5.]
# Iteration :  127
# Index of best -[1 0 7 6 5 2 4 3]
# Best qualites -[-4. -4. -5. -5. -5. -5. -6. -6.]
# Quality:  [-4. -4. -5. -6. -6. -6. -5. -6.]
# Iteration :  128
# Index of best -[1 0 6 2 7 5 4 3]
# Best qualites -[-4. -4. -5. -5. -6. -6. -6. -6.]
# Quality:  [-4. -4. -5. -6. -4. -6. -5. -5.]
# Iteration :  129
# Index of best -[4 1 0 7 6 2 5 3]
# Best qualites -[-4. -4. -4. -5. -5. -5. -6. -6.]
# Quality:  [-4. -4. -4. -5. -5. -4. -4. -5.]
# Iteration :  130
# Index of best -[6 5 2 1 0 7 4 3]
# Best qualites -[-4. -4. -4. -4. -4. -5. -5. -5.]
# Quality:  [-4. -4. -4. -5. -6. -5. -4. -5.]
# Iteration :  131
# Index of best -[6 2 1 0 7 5 3 4]
# Best qualites -[-4. -4. -4. -4. -5. -5. -5. -6.]
# Quality:  [-4. -4. -4. -5. -4. -5. -5. -5.]
# Iteration :  132
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-4. -4. -4. -4. -5. -5. -5. -5.]
# Quality:  [-4. -4. -4. -6. -5. -4. -4. -4.]
# Iteration :  133
# Index of best -[7 6 5 2 1 0 4 3]
# Best qualites -[-4. -4. -4. -4. -4. -4. -5. -6.]
# Quality:  [-4. -4. -4. -2. -5. -6. -4. -4.]
# Iteration :  134
# Index of best -[3 7 6 2 1 0 4 5]
# Best qualites -[-2. -4. -4. -4. -4. -4. -5. -6.]
# Quality:  [-2. -4. -4. -6. -4. -4. -4. -6.]
# Iteration :  135
# Index of best -[0 6 5 4 2 1 7 3]
# Best qualites -[-2. -4. -4. -4. -4. -4. -6. -6.]
# Quality:  [-2. -4. -4. -3. -6. -3. -6. -4.]
# Iteration :  136
# Index of best -[0 5 3 7 2 1 6 4]
# Best qualites -[-2. -3. -3. -4. -4. -4. -6. -6.]
# Quality:  [-2. -3. -3. -4. -4. -5. -2. -2.]
# Iteration :  137
# Index of best -[7 6 0 2 1 4 3 5]
# Best qualites -[-2. -2. -2. -3. -3. -4. -4. -5.]
# Quality:  [-2. -2. -2. -4. -3. -1. -3. -3.]
# Iteration :  138
# Index of best -[5 2 1 0 7 6 4 3]
# Best qualites -[-1. -2. -2. -2. -3. -3. -3. -4.]
# Quality:  [-1. -2. -2. -3. -3. -2. -3. -4.]
# Iteration :  139
# Index of best -[0 5 2 1 6 4 3 7]
# Best qualites -[-1. -2. -2. -2. -3. -3. -3. -4.]
# Quality:  [-1. -2. -2. -4. -3. -2. -2. -3.]
# Iteration :  140
# Index of best -[0 6 5 2 1 7 4 3]
# Best qualites -[-1. -2. -2. -2. -2. -3. -3. -4.]
# Quality:  [-1. -2. -2. -2. -2. -2. -2. -3.]
# Iteration :  141
# Index of best -[0 6 5 4 3 2 1 7]
# Best qualites -[-1. -2. -2. -2. -2. -2. -2. -3.]
# Quality:  [-1. -2. -2. -3. -3. -2. -1. -2.]
# Iteration :  142
# Index of best -[6 0 7 5 2 1 4 3]
# Best qualites -[-1. -1. -2. -2. -2. -2. -3. -3.]
# Quality:  [-1. -1. -2. -3. -2. -2. -4. -3.]
# Iteration :  143
# Index of best -[1 0 5 4 2 7 3 6]
# Best qualites -[-1. -1. -2. -2. -2. -3. -3. -4.]
# Quality:  [-1. -1. -2. -4. -2. -3. -3. -3.]
# Iteration :  144
# Index of best -[1 0 4 2 7 6 5 3]
# Best qualites -[-1. -1. -2. -2. -3. -3. -3. -4.]
# Quality:  [-1. -1. -2. -2. -1. -4. -2. -2.]
# Iteration :  145
# Index of best -[4 1 0 7 6 3 2 5]
# Best qualites -[-1. -1. -1. -2. -2. -2. -2. -4.]
# Quality:  [-1. -1. -1. -1. -2. -3. -2. -3.]
# Iteration :  146
# Index of best -[3 2 1 0 6 4 7 5]
# Best qualites -[-1. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-1. -1. -1. -2. -1. -3. -2. -3.]
# Iteration :  147
# Index of best -[4 2 1 0 6 3 7 5]
# Best qualites -[-1. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-1. -1. -1. -3. -3. -2. -1. -3.]
# Iteration :  148
# Index of best -[6 2 1 0 5 7 4 3]
# Best qualites -[-1. -1. -1. -1. -2. -3. -3. -3.]
# Quality:  [-1. -1. -1. -2. -1. -2. -2. -2.]
# Iteration :  149
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-1. -1. -1. -1. -2. -2. -2. -2.]
# Quality:  [-1. -1. -1. -2. -1. -1. -1. -1.]
# Iteration :  150
# Index of best -[7 6 5 4 2 1 0 3]
# Best qualites -[-1. -1. -1. -1. -1. -1. -1. -2.]
# Quality:  [-1. -1. -1. -2. -2. -3. -3. -1.]
# Iteration :  151
# Index of best -[7 2 1 0 4 3 6 5]
# Best qualites -[-1. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-1. -1. -1. -3. -1. -2. -2. -2.]
# Iteration :  152
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-1. -1. -1. -1. -2. -2. -2. -3.]
# Quality:  [-1. -1. -1. -2. -3. -2. -2. -2.]
# Iteration :  153
# Index of best -[2 1 0 7 6 5 3 4]
# Best qualites -[-1. -1. -1. -2. -2. -2. -2. -3.]
# Quality:  [-1. -1. -1. -1. -3. -2. -1. -2.]
# Iteration :  154
# Index of best -[6 3 2 1 0 7 5 4]
# Best qualites -[-1. -1. -1. -1. -1. -2. -2. -3.]
# Quality:  [-1. -1. -1. -2. -3. -2. -3. -0.]
# Iteration :  155
# Index of best -[7 2 1 0 5 3 6 4]
# Best qualites -[-0. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-0. -1. -1. -2. -2. -2. -2. -1.]
# Iteration :  156
# Index of best -[0 7 2 1 6 5 4 3]
# Best qualites -[-0. -1. -1. -1. -2. -2. -2. -2.]
# Quality:  [-0. -1. -1. -2. -1. -1. -3. -2.]
# Iteration :  157
# Index of best -[0 5 4 2 1 7 3 6]
# Best qualites -[-0. -1. -1. -1. -1. -2. -2. -3.]
# Quality:  [-0. -1. -1. -1. -2. -2. -3. -2.]
# Iteration :  158
# Index of best -[0 3 2 1 7 5 4 6]
# Best qualites -[-0. -1. -1. -1. -2. -2. -2. -3.]
# Quality:  [-0. -1. -1. -3. -2. -2. -1. -3.]
# Iteration :  159
# Index of best -[0 6 2 1 5 4 7 3]
# Best qualites -[-0. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-0. -1. -1. -2. -3. -1. -3. -2.]
# Iteration :  160
# Index of best -[0 5 2 1 7 3 6 4]
# Best qualites -[-0. -1. -1. -1. -2. -2. -3. -3.]
# Quality:  [-0. -1. -1. -0. -2. -1. -0. -2.]
# Iteration :  161
# Index of best -[6 3 0 5 2 1 7 4]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -2. -1. -1. -1.]
# Iteration :  162
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -0. -2. -2. -1.]
# Iteration :  163
# Index of best -[4 3 2 1 0 7 6 5]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -1. -0.]
# Iteration :  164
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -2. -0. -1. -1.]
# Iteration :  165
# Index of best -[5 2 1 0 7 6 3 4]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -1.]
# Iteration :  166
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -1. -1. -1. -2.]
# Iteration :  167
# Index of best -[3 2 1 0 6 5 4 7]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -2. -1.]
# Iteration :  168
# Index of best -[2 1 0 7 5 4 3 6]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -0. -1. -0.]
# Iteration :  169
# Index of best -[7 5 4 2 1 0 6 3]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -1.]
# Quality:  [-0. -0. -0. -1. -0. -1. -1. -1.]
# Iteration :  170
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -0. -1. -0. -0.]
# Iteration :  171
# Index of best -[7 6 4 2 1 0 5 3]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -1.]
# Quality:  [-0. -0. -0. -1. -0. -0. -1. -1.]
# Iteration :  172
# Index of best -[5 4 2 1 0 7 6 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -2.]
# Iteration :  173
# Index of best -[2 1 0 6 5 4 3 7]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -1. -2. -1.]
# Iteration :  174
# Index of best -[4 2 1 0 7 5 3 6]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -1. -1. -2. -1.]
# Iteration :  175
# Index of best -[2 1 0 7 5 4 6 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -2. -1. -0. -0.]
# Iteration :  176
# Index of best -[7 6 2 1 0 5 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -1. -0. -1. -0.]
# Iteration :  177
# Index of best -[7 5 2 1 0 6 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -0. -2. -2.]
# Iteration :  178
# Index of best -[5 2 1 0 4 3 7 6]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -0. -1.]
# Iteration :  179
# Index of best -[6 2 1 0 7 5 4 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -0. -1. -1. -0.]
# Iteration :  180
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -1. -0. -1.]
# Iteration :  181
# Index of best -[6 2 1 0 7 5 4 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -2. -2. -1. -2.]
# Iteration :  182
# Index of best -[3 2 1 0 6 7 5 4]
# Best qualites -[-0. -0. -0. -0. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -0. -2. -1. -0. -1.]
# Iteration :  183
# Index of best -[6 3 2 1 0 7 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -0. -0. -1. -1.]
# Iteration :  184
# Index of best -[5 4 2 1 0 7 6 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -2. -1. -1. -1.]
# Iteration :  185
# Index of best -[3 2 1 0 7 6 5 4]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -2. -2. -0. -1.]
# Iteration :  186
# Index of best -[6 2 1 0 7 3 5 4]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -2. -1.]
# Iteration :  187
# Index of best -[4 2 1 0 7 5 6 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -1. -0. -0. -2.]
# Iteration :  188
# Index of best -[6 5 3 2 1 0 4 7]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -2.]
# Quality:  [-0. -0. -0. -2. -1. -1. -2. -2.]
# Iteration :  189
# Index of best -[2 1 0 5 4 7 6 3]
# Best qualites -[-0. -0. -0. -1. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -0. -2.]
# Iteration :  190
# Index of best -[6 4 2 1 0 5 7 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -0. -2. -1. -2.]
# Iteration :  191
# Index of best -[4 2 1 0 6 3 7 5]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -1. -2. -0. -0.]
# Iteration :  192
# Index of best -[7 6 3 2 1 0 4 5]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -1.]
# Iteration :  193
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -2. -1. -1.]
# Iteration :  194
# Index of best -[2 1 0 7 6 4 3 5]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -0. -2. -0. -0.]
# Iteration :  195
# Index of best -[7 6 4 3 2 1 0 5]
# Best qualites -[-0. -0. -0. -0. -0. -0. -0. -2.]
# Quality:  [-0. -0. -0. -2. -0. -2. -2. -0.]
# Iteration :  196
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[-0. -0. -0. -0. -0. -2. -2. -2.]
# Quality:  [-0. -0. -0. -1. -1. -0. -0. -1.]
# Iteration :  197
# Index of best -[6 5 2 1 0 7 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -1.]
# Iteration :  198
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -2. -2. -2. -1.]
# Iteration :  199
# Index of best -[2 1 0 7 3 6 5 4]
# Best qualites -[-0. -0. -0. -1. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -2. -2. -2. -0. -1.]
# Iteration :  200
# Index of best -[6 2 1 0 7 5 4 3]
# Best qualites -[-0. -0. -0. -0. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -0. -0. -1. -1. -2.]
# Iteration :  201
# Index of best -[4 3 2 1 0 6 5 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -2. -0.]
# Iteration :  202
# Index of best -[7 2 1 0 5 4 3 6]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -2. -1. -0. -0.]
# Iteration :  203
# Index of best -[7 6 2 1 0 5 3 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -2. -2. -2. -0.]
# Iteration :  204
# Index of best -[7 2 1 0 6 5 4 3]
# Best qualites -[-0. -0. -0. -0. -2. -2. -2. -2.]
# Quality:  [-0. -0. -0. -2. -1. -0. -0. -2.]
# Iteration :  205
# Index of best -[6 5 2 1 0 4 7 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -1. -2. -0. -1.]
# Iteration :  206
# Index of best -[6 2 1 0 7 4 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -2. -1. -0. -0.]
# Iteration :  207
# Index of best -[7 6 2 1 0 5 3 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -0. -0. -2.]
# Iteration :  208
# Index of best -[6 5 4 2 1 0 3 7]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -0. -0. -1.]
# Iteration :  209
# Index of best -[6 5 2 1 0 7 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -1. -0. -2.]
# Iteration :  210
# Index of best -[6 2 1 0 5 4 3 7]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -1. -1. -1. -2.]
# Iteration :  211
# Index of best -[2 1 0 6 5 4 7 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -1. -1.]
# Iteration :  212
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -1. -2.]
# Iteration :  213
# Index of best -[4 2 1 0 6 5 7 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -1. -1. -0. -0.]
# Iteration :  214
# Index of best -[7 6 3 2 1 0 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -2. -0. -2.]
# Iteration :  215
# Index of best -[6 2 1 0 4 3 7 5]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -2. -1. -1. -0.]
# Iteration :  216
# Index of best -[7 3 2 1 0 6 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -2. -1. -1. -2.]
# Iteration :  217
# Index of best -[3 2 1 0 6 5 7 4]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -2. -1.]
# Iteration :  218
# Index of best -[2 1 0 7 5 4 3 6]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -2. -1. -1. -0.]
# Iteration :  219
# Index of best -[7 3 2 1 0 6 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -2. -2. -0. -1.]
# Iteration :  220
# Index of best -[6 3 2 1 0 7 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -2. -0. -2. -2. -0.]
# Iteration :  221
# Index of best -[7 4 2 1 0 6 5 3]
# Best qualites -[-0. -0. -0. -0. -0. -2. -2. -2.]
# Quality:  [-0. -0. -0. -1. -2. -1. -1. -1.]
# Iteration :  222
# Index of best -[2 1 0 7 6 5 3 4]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -1.]
# Iteration :  223
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -0. -1. -0. -2.]
# Iteration :  224
# Index of best -[6 4 2 1 0 5 3 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -1. -1. -1.]
# Iteration :  225
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -0. -2. -2. -1.]
# Iteration :  226
# Index of best -[4 3 2 1 0 7 6 5]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -1. -1. -0. -2.]
# Iteration :  227
# Index of best -[6 3 2 1 0 5 4 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -2. -2. -1. -1.]
# Iteration :  228
# Index of best -[2 1 0 7 6 3 5 4]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -1. -0. -0. -1.]
# Iteration :  229
# Index of best -[6 5 2 1 0 7 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -1. -1. -1. -2.]
# Iteration :  230
# Index of best -[3 2 1 0 6 5 4 7]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -1. -1. -1. -2.]
# Iteration :  231
# Index of best -[2 1 0 6 5 4 3 7]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -0. -1. -1.]
# Iteration :  232
# Index of best -[5 4 2 1 0 7 6 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -0. -0. -2. -1.]
# Iteration :  233
# Index of best -[5 4 3 2 1 0 7 6]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -2.]
# Quality:  [-0. -0. -0. -2. -1. -1. -1. -0.]
# Iteration :  234
# Index of best -[7 2 1 0 6 5 4 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -1. -1. -2. -0.]
# Iteration :  235
# Index of best -[7 3 2 1 0 5 4 6]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -2. -2. -1. -1. -1.]
# Iteration :  236
# Index of best -[2 1 0 7 6 5 4 3]
# Best qualites -[-0. -0. -0. -1. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -0. -2. -2. -0. -1.]
# Iteration :  237
# Index of best -[6 3 2 1 0 7 5 4]
# Best qualites -[-0. -0. -0. -0. -0. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -0. -1. -1. -1.]
# Iteration :  238
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -0. -0. -1.]
# Iteration :  239
# Index of best -[6 5 2 1 0 7 4 3]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -1.]
# Quality:  [-0. -0. -0. -0. -1. -0. -1. -0.]
# Iteration :  240
# Index of best -[7 5 3 2 1 0 6 4]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -1.]
# Quality:  [-0. -0. -0. -1. -1. -2. -2. -2.]
# Iteration :  241
# Index of best -[2 1 0 4 3 7 6 5]
# Best qualites -[-0. -0. -0. -1. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -1. -2. -1. -1. -1.]
# Iteration :  242
# Index of best -[2 1 0 7 6 5 3 4]
# Best qualites -[-0. -0. -0. -1. -1. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -0. -1. -1. -2.]
# Iteration :  243
# Index of best -[4 3 2 1 0 6 5 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -0. -2. -2. -2. -1.]
# Iteration :  244
# Index of best -[3 2 1 0 7 6 5 4]
# Best qualites -[-0. -0. -0. -0. -1. -2. -2. -2.]
# Quality:  [-0. -0. -0. -1. -0. -1. -0. -2.]
# Iteration :  245
# Index of best -[6 4 2 1 0 5 3 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -0. -1. -2.]
# Iteration :  246
# Index of best -[5 4 2 1 0 6 3 7]
# Best qualites -[-0. -0. -0. -0. -0. -1. -1. -2.]
# Quality:  [-0. -0. -0. -1. -0. -2. -2. -1.]
# Iteration :  247
# Index of best -[4 2 1 0 7 3 6 5]
# Best qualites -[-0. -0. -0. -0. -1. -1. -2. -2.]
# Quality:  [-0. -0. -0. -1. -0. -0. -2. -0.]
# Iteration :  248
# Index of best -[7 5 4 2 1 0 3 6]
# Best qualites -[-0. -0. -0. -0. -0. -0. -1. -2.]
# Quality:  [-0. -0. -0. -2. -0. -1. -1. -1.]
# Iteration :  249
# Index of best -[4 2 1 0 7 6 5 3]
# Best qualites -[-0. -0. -0. -0. -1. -1. -1. -2.]

# %% [markdown]
# ### 11. Visualization

# %%
folder_path = 'image'
file_names = sorted([f for f in os.listdir(folder_path) if f.endswith('.png')], key=natural_sort_key)
mp4_file = 'evolution.mp4'
with imageio.get_writer(mp4_file, fps=5) as writer:
    for filename in file_names:
        image = imageio.imread(os.path.join(folder_path, filename))
        writer.append_data(image)
print(f"MP4 created successfully: {mp4_file}")
# Out:
# C:\Users\sachi\AppData\Local\Temp\ipykernel_18832\1592571157.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(os.path.join(folder_path, filename))
# MP4 created successfully: evolution.mp4
